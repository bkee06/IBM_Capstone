# %% [markdown]
# <a href="https://colab.research.google.com/github/bkee06/IBM_Capstone/blob/main/Final_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IBM Data Science Capstone - Bean by Drone
#
# This notebook contains the Final Report for the Capstone project for IBM Applied Data Science.
#
# *Written by B Kee.*

# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# # Project Aim:
# To analise the potential locations for drone delivery hubs based on proximity to playgrounds and subsequently select the highest rated Coffee Shop in each cluster to approach for a colaboration.
#
# # Background:
# My client has approached me with a business proposition to start a drone delivery company in Canberra, Australian Capital Territory (ACT), Australia.
#
# The initial stage will be market research and a proof of concept, hence they would like to deliver a single product that is highly consumable and small.
#
# To reduce initial risk and aid in ease of delivery, large open areas would be preferable for delivery locations.
#
# # Proposal:
# Product - I have suggested coffee is a product that is easy to produce, small and has high consumption rates.
#
# Delivery Zones - As Canberra has a large amount of public open space spread though out the populated area I have suggested that local playgrounds would provide a good delivery zone.
#
# Colaboration - To ensure customers participate in the initial trial a well recognised brand that is local and highly regarded in each location is required.
#
# # Audience/Stakeholders:
# 1. Bean by Drone - Business owner
# 2. Local Council - delevopment approval for delivery zones
# 3. Local public - feedback and promotion.
#
#
# # Datasets:
#
# The Australian Government has a variety of datasets at Data.gov.au. One such data set is a polygon shapefile of all playgrounds in Canberra.
#
# [Australian Government - Data.gov.au - ACT Playground Datasets.](https://data.gov.au/dataset/ds-actmapi-https%3A%2F%2Factmapi-actgov.opendata.arcgis.com%2Fdatasets%2F6baffe02451d47baa1c13626b21f43a8_6/details?q=act%20playgrounds)
#
# # API's:
#
# The use of the FourSquare product in Australia has been limited, hence there is a limited amount of data available via their API.
#
# Several alternate sources were proposed:
#
# *   Google Maps
# *   Trip Advisor
# *   Yelp
#
# I chose the Yelp API due to ease of use, cost and quantity of data.
#
# [Yelp - Web Data API Documentation](https://www.yelp.com/fusion)
#
# # Required Data:
#
# * Playground Locations: Provided via geoJson, csv or shapefile
# * Clusters: number required and location
# * Coffee Shop Information:
#
# > 1. Name,
# > 2. Customer Rating,
# > 3. Lat/Long.
#
# # Analysis:
#
# * Playgrounds: Find single reference lat/long for each
# * Clusters:
#
# > 1. Determine the optimum number of Drone Hubs (K),
# > 2. Cluster playgrounds based on number of Hubs (K_means),
# > 3. Determine the center point of each Hub (K_means_centers).
#
# * Coffee Shops:
#
# > 1. Locate based on Drone Hub locations (Yelp API),
# > 2. Select based on customer ratings (Yelp API).
#
# # Deliverables:
#
# * Map of data points for:
#
# >1. Playgrounds,
# >2. Hub Locations (cluster centres),
# >3. Coffee Shop Locations
#
# * File containing:
#
# >1. Coffee Shop Name, Address, Latitude, Longitude,
# >2. Done Hub Latitude, Longitude (cluster centers)

# %% [markdown]
# # **Methodology**

# %% [markdown]
# #Initial Market Research:
#
# Data was colllected on consumer trends in Australia during covid. It was shown that coffee consumption at home had increased and dine in patronage had decreased. Canberra also has a high percentage of the population that regulary visit Coffee Shops. Therefore coffee was considered a good intitial product to deliver as it provided cafe quality coffee without the need to visit a physical address.
#
# [Coffee Consuption during Covid Report.](https://www.adnews.com.au/news/pandemic-habits-coffee-drinking-has-changed-in-australia)
#
# [Canberreans Highest National Average of Coffee Shop patronage. ](https://www.goodfood.com.au/drinks/canberra-a-city-of-coffee-snobs-survey-finds-20150326-1m7873)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Playgrounds were selected as a logical delivery site as they provided a safe open space, were located in populated areas and were frequented by a demographic that consumes coffee during the day and may have limited ability to access coffee shops.

# %% [markdown]
# # Import Data:
#
# Firstly the dataset for the playground locations needed to be imported from a shapefile. The geopandas library was used to collect the data and import it into a dataframe. The data was cleaned to remove unnesacery columns, compute the centroid of the polygons and subsequently exctract the latitude and longitude.
#
# The dataset also needed to be converted to an appropriate Cooridinate Reference System for plotting.
#
# The resulting data set is shown below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Additional information was produced to help visulise the data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The playground data points were then plotted to also aid with visulisation of the data. The resulting plot was a near match to the popluated are of Canberra.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To ensure the float data that represented the lat/long data was correct a plotly scatter plot was used to visulise the data. This was a match to the geopandas plot and showed the lat/long data had been extracted correctly.

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()

# %% [markdown]
# # K Means Analysis:
#
# As the play grounds were being used to provide information on potential drone huub site they needed to be grouped into logical clusters.
#
# An analysis of the k means scores was conducted and plotted as shown below.
#
# The optimum number of clustes was 5.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using a k means analysis with 5 clustes the following cluster centres were determined. A visualisation of this was also plotted to check the accuracy of the analysis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The data was also used to produce a map of the playgrounds and the cluster centres to aid in analysing the data and checking accuracy.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Extracting Coffee Shop data via Yelp API:
#
# A loop was then used to call the Yelp API with the lat, long and range of the cluster centres. This returned the highest rated coffee shop within a 3000m radius based on user reviews from Yelp.
#
# This data was printed to screen. Additional cleaning and data manipulation resulted in a dataframe that contained all relevant data and was also saved to a CSV file for later use.

# %% [markdown]
# # Create a final Interactive Map:
#
# The final data was used to create a map with indiviual points for playgrounds, cluster centres and coffee shop locations with interactive popup labels.

# %% [markdown]
# #**Results**

# %% [markdown]
# # Source Code:
#
# [Source Code GitHub Repo.](https://github.com/bkee06/IBM_Capstone/blob/main/Yelp_cap.ipynb)

# %% [markdown]
# # Final Results:
#
# The higest rated coffee shops were selected for each cluster. This information was also output to a csv file.
#
# [Coffee Shop Details CSV](https://github.com/bkee06/IBM_Capstone/blob/main/shop_df.csv)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Final Map:
#
# The map below shows the following:
#
# > 1. Blue - Individual Playgrounds,
# > 2. Red - Cluster Centres,
# > 3. Yellow - Coffee Shop Locations.
#
# The source code and [blog site](https://) provide an interactive version with point labels (listed below).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Discussion**
#
# Please refer to my blog post for futher discussion:
#
# [Bean by Drone - Blog](https://)

# %% [markdown]
# #**Further Research**
#
# Further analysis could include the following:
#
# > 1. Cost of delivery service,
# > 2. Peak demand periods,
# > 3. Most consumed coffee types,
# > 4. Cost of a cup of coffee.
#
# This data maybe sourced from theh Square API:
#
# [Coffee Data - Square](https://squareup.com/au/en/townsquare/2019-australian-coffee-report)

# %% [markdown]
# # **Conclusion**
#
# The analysis this far has show that drone delivery in Canberra could work with 5 Hub locations. This would provide the best coverage of the metropolitan area and the Canberra population. Coffee was selected as the intial product due to its size, ease of production and research suggesting consumer demand is unmet due to covid restrictions. Customer ratings were analysed to select highly rated and recognised local brands.
#
# The project will now progress to the costing phase to further determine feasibility.
